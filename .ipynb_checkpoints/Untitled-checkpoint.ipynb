# %%
from ultralytics import YOLO
import cv2
from twilio.rest import Client
import time
import torch  


ACCOUNT_SID = 'AC47d17571f10a41b2218902931d475ff7'
AUTH_TOKEN = '1dd091d64972b9115ede159712f8d08b'
TWILIO_PHONE_NUMBER = '+18106708405'
RECIPIENT_PHONE_NUMBER = '+255673882243'

CRIME_CLASSES = {"knife", "gun"}  

client = Client(ACCOUNT_SID, AUTH_TOKEN)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on: {DEVICE}")

def send_sms_alert(message_body):
    """Sends an SMS alert using Twilio and ensures successful delivery."""
    try:
        message = client.messages.create(
            body=message_body,
            from_=TWILIO_PHONE_NUMBER,
            to=RECIPIENT_PHONE_NUMBER
        )
        print(f"SMS successfully sent: {message.sid}")
    except Exception as e:
        print(f"Failed to send SMS: {e}")

def load_model(model_path='yolov8l.pt'):
    """Loads the YOLO model with automatic device selection."""
    model = YOLO(model_path)
    model.to(DEVICE) 
    return model

def detect_objects_webcam(model):
    """Runs object detection using the webcam."""
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        return
    
    last_sms_time = 0  
    sms_cooldown = 60 
    frame_skip = 2  
    frame_count = 0

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print("Error: Failed to capture image.")
                break

            frame_count += 1
            if frame_count % frame_skip != 0:
                continue  

            results = model.predict(frame, conf=0.5, device=DEVICE)  
            crime_detected = False

            for result in results:
                for box in result.boxes:
                    if hasattr(box, "cls") and len(box.cls) > 0:  
                        cls_id = int(box.cls[0])
                        class_name = model.model.names.get(cls_id, "Unknown")  

                        if class_name in CRIME_CLASSES:
                            crime_detected = True 
                            current_time = time.time()
                            if current_time - last_sms_time > sms_cooldown:
                                send_sms_alert(f"ALERT! {class_name} detected! Take action immediately.")
                                last_sms_time = current_time  

                frame = result.plot()
        
            if crime_detected:
                cv2.putText(frame, "WARNING: CRIME DETECTED!", (50, 50), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3, cv2.LINE_AA)

            cv2.imshow('YOLO Object Detection - Webcam', frame)

            if cv2.waitKey(1) & 0xFF == ord('q') or cv2.getWindowProperty('YOLO Object Detection - Webcam', cv2.WND_PROP_VISIBLE) < 1:
                break

    except Exception as e:
        print(f"Error: {e}")
    
    finally:
        cap.release()  
        cv2.destroyAllWindows()

if __name__ == "__main__":
    model = load_model()  
    detect_objects_webcam(model)
# Out:
# Running on: cpu
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8l.pt to 'yolov8l.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 83.7M/83.7M [01:15<00:00, 1.16MB/s]
# 0: 480x640 2 persons, 1086.7ms
# Speed: 4.7ms preprocess, 1086.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 743.2ms
# Speed: 3.4ms preprocess, 743.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 739.7ms
# Speed: 2.0ms preprocess, 739.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 725.9ms
# Speed: 2.2ms preprocess, 725.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 675.6ms
# Speed: 3.2ms preprocess, 675.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 653.8ms
# Speed: 3.1ms preprocess, 653.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 633.1ms
# Speed: 3.0ms preprocess, 633.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 585.4ms
# Speed: 3.4ms preprocess, 585.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 625.2ms
# Speed: 2.8ms preprocess, 625.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 609.2ms
# Speed: 1.9ms preprocess, 609.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 615.0ms
# Speed: 3.2ms preprocess, 615.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 696.6ms
# Speed: 2.0ms preprocess, 696.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons,
9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 738.4ms
# Speed: 2.7ms preprocess, 738.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 839.6ms
# Speed: 2.8ms preprocess, 839.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 766.9ms
# Speed: 3.0ms preprocess, 766.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 surfboard, 724.8ms
# Speed: 3.1ms preprocess, 724.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 707.4ms
# Speed: 2.5ms preprocess, 707.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 741.7ms
# Speed: 2.4ms preprocess, 741.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 745.1ms
# Speed: 3.0ms preprocess, 745.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 756.9ms
# Speed: 2.7ms preprocess, 756.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 758.2ms
# Speed: 2.8ms preprocess, 758.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 736.4ms
# Speed: 2.5ms preprocess, 736.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 754.8ms
# Speed: 3.0ms preprocess, 754.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 807.7ms
# Speed: 3.1ms preprocess, 807.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 736.1ms
# Speed: 2.7ms preprocess, 736.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 750.6ms
# Speed: 2.8ms preprocess, 750.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 747.7ms
# Speed: 3.0ms preprocess, 747.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 737.9ms
# Speed: 2.7ms preprocess, 737.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 773.5ms
# Speed: 2.9ms preprocess, 773.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 744.0ms
# Speed: 3.0ms preprocess, 744.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 744.9ms
# Speed: 2.6ms preprocess, 744.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 knife, 744.8ms
# Speed: 2.4ms preprocess, 744.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 knife, 750.2ms
# Speed: 2.5ms preprocess, 750.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 740.3ms
# Speed: 2.7ms preprocess, 740.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 knife, 742.9ms
# Speed: 2.7ms preprocess, 742.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 knife, 1 scissors, 785.3ms
# Speed: 2.7ms preprocess, 785.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 knife, 740.0ms
# Speed: 2.7ms preprocess, 740.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 knife, 1 scissors, 739.3ms
# Speed: 2.6ms preprocess, 739.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 740.5ms
# Speed: 2.4ms preprocess, 740.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 scissors, 739.5ms
# Speed: 2.8ms preprocess, 739.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 scissors, 738.6ms
# Speed: 2.4ms preprocess, 738.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 knife, 740.2ms
# Speed: 2.8ms preprocess, 740.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 732.9ms
# Speed: 3.1ms preprocess, 732.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 737.4ms
# Speed: 2.7ms preprocess, 737.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 740.6ms
# Speed: 2.7ms preprocess, 740.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 735.6ms
# Speed: 2.9ms preprocess, 735.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 766.3ms
# Speed: 2.7ms preprocess, 766.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 748.1ms
# Speed: 2.7ms preprocess, 748.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 798.9ms
# Speed: 2.6ms preprocess, 798.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 775.1ms
# Speed: 2.6ms preprocess, 775.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 746.3ms
# Speed: 2.4ms preprocess, 746.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)

# %%
#!pip install twilio
# Out:
# Collecting twilio
#   Downloading twilio-9.5.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\lynix\anaconda3\lib\site-packages (from twilio) (2.32.3)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in c:\users\lynix\anaconda3\lib\site-packages (from twilio) (2.8.0)
# Requirement already satisfied: aiohttp>=3.8.4 in c:\users\lynix\anaconda3\lib\site-packages (from twilio) (3.10.5)
# Collecting aiohttp-retry>=2.8.3 (from twilio)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lynix\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lynix\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lynix\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lynix\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2025.1.31)
# Downloading twilio-9.5.1-py2.py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.9 MB 762.0 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/1.9 MB 907.1 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.0/1.9 MB 986.7 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.9 MB 1.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.6/1.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 1.1 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Installing collected packages: aiohttp-retry, twilio
# Successfully installed aiohttp-retry-2.9.1 twilio-9.5.1
