# %%
from ultralytics import YOLO
import cv2
from twilio.rest import Client
import time
import torch  


ACCOUNT_SID = 'AC47d17571f10a41b2218902931d475ff7'
AUTH_TOKEN = '1dd091d64972b9115ede159712f8d08b'
TWILIO_PHONE_NUMBER = '+18106708405'
RECIPIENT_PHONE_NUMBER = '+255673882243'

CRIME_CLASSES = {"knife", "gun"}  

client = Client(ACCOUNT_SID, AUTH_TOKEN)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on: {DEVICE}")

def send_sms_alert(message_body):
    """Sends an SMS alert using Twilio and ensures successful delivery."""
    try:
        message = client.messages.create(
            body=message_body,
            from_=TWILIO_PHONE_NUMBER,
            to=RECIPIENT_PHONE_NUMBER
        )
        print(f"SMS successfully sent: {message.sid}")
    except Exception as e:
        print(f"Failed to send SMS: {e}")

def load_model(model_path='yolov8l.pt'):
    """Loads the YOLO model with automatic device selection."""
    model = YOLO(model_path)
    model.to(DEVICE) 
    return model

def detect_objects_webcam(model):
    """Runs object detection using the webcam."""
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open webcam.")
        return
    
    last_sms_time = 0  
    sms_cooldown = 60 
    frame_skip = 2  
    frame_count = 0

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print("Error: Failed to capture image.")
                break

            frame_count += 1
            if frame_count % frame_skip != 0:
                continue  

            results = model.predict(frame, conf=0.5, device=DEVICE)  
            crime_detected = False

            for result in results:
                for box in result.boxes:
                    if hasattr(box, "cls") and len(box.cls) > 0:  
                        cls_id = int(box.cls[0])
                        class_name = model.model.names.get(cls_id, "Unknown")  

                        if class_name in CRIME_CLASSES:
                            crime_detected = True 
                            current_time = time.time()
                            if current_time - last_sms_time > sms_cooldown:
                                send_sms_alert(f"ALERT! {class_name} detected! Take action immediately.")
                                last_sms_time = current_time  

                frame = result.plot()
        
            if crime_detected:
                cv2.putText(frame, "WARNING: CRIME DETECTED!", (50, 50), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3, cv2.LINE_AA)

            cv2.imshow('YOLO Object Detection - Webcam', frame)

            if cv2.waitKey(1) & 0xFF == ord('q') or cv2.getWindowProperty('YOLO Object Detection - Webcam', cv2.WND_PROP_VISIBLE) < 1:
                break

    except Exception as e:
        print(f"Error: {e}")
    
    finally:
        cap.release()  
        cv2.destroyAllWindows()

if __name__ == "__main__":
    model = load_model()  
    detect_objects_webcam(model)
# Out:
# Running on: cpu
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8l.pt to 'yolov8l.pt'...
# 100%|██████████████████████████████████████████████████████████████████████████████| 83.7M/83.7M [11:10<00:00, 131kB/s]
# 0: 480x640 (no detections), 731.9ms
# Speed: 3.5ms preprocess, 731.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 587.0ms
# Speed: 2.3ms preprocess, 587.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 543.9ms
# Speed: 2.0ms preprocess, 543.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 531.5ms
# Speed: 2.0ms preprocess, 531.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 522.0ms
# Speed: 1.9ms preprocess, 522.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 533.0ms
# Speed: 1.9ms preprocess, 533.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 561.8ms
# Speed: 2.6ms preprocess, 561.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 536.7ms
# Speed: 1.8ms preprocess, 536.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections),
7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 709.1ms
# Speed: 3.2ms preprocess, 709.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 850.0ms
# Speed: 3.0ms preprocess, 850.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 816.2ms
# Speed: 3.5ms preprocess, 816.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 757.3ms
# Speed: 3.0ms preprocess, 757.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 775.7ms
# Speed: 2.8ms preprocess, 775.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 736.4ms
# Speed: 2.6ms preprocess, 736.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 704.8ms
# Speed: 2.1ms preprocess, 704.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 660.2ms
# Speed: 2.5ms preprocess, 660.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 682.7ms
# Speed: 2.3ms preprocess, 682.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 696.1ms
# Speed: 2.3ms preprocess, 696.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 705.3ms
# Speed: 2.7ms preprocess, 705.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 709.1ms
# Speed: 2.5ms preprocess, 709.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 710.3ms
# Speed: 2.4ms preprocess, 710.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 717.9ms
# Speed: 2.7ms preprocess, 717.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 787.6ms
# Speed: 2.7ms preprocess, 787.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 756.6ms
# Speed: 2.6ms preprocess, 756.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 795.2ms
# Speed: 2.7ms preprocess, 795.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 710.2ms
# Speed: 2.9ms preprocess, 710.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 715.6ms
# Speed: 2.6ms preprocess, 715.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 719.6ms
# Speed: 2.6ms preprocess, 719.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 758.5ms
# Speed: 2.6ms preprocess, 758.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 712.5ms
# Speed: 2.6ms preprocess, 712.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 697.2ms
# Speed: 2.7ms preprocess, 697.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 688.2ms
# Speed: 3.0ms preprocess, 688.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 712.9ms
# Speed: 2.8ms preprocess, 712.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 731.4ms
# Speed: 3.0ms preprocess, 731.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 700.9ms
# Speed: 2.4ms preprocess, 700.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 713.4ms
# Speed: 2.5ms preprocess, 713.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 712.1ms
# Speed: 2.6ms preprocess, 712.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 697.2ms
# Speed: 3.0ms preprocess, 697.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 703.6ms
# Speed: 2.2ms preprocess, 703.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 704.0ms
# Speed: 2.6ms preprocess, 704.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 696.5ms
# Speed: 3.2ms preprocess, 696.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 765.0ms
# Speed: 2.7ms preprocess, 765.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 706.0ms
# Speed: 2.4ms preprocess, 706.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 721.4ms
# Speed: 2.9ms preprocess, 721.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 749.5ms
# Speed: 2.7ms preprocess, 749.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 718.2ms
# Speed: 2.6ms preprocess, 718.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 730.3ms
# Speed: 3.2ms preprocess, 730.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 736.8ms
# Speed: 3.0ms preprocess, 736.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 tv, 718.2ms
# Speed: 3.2ms preprocess, 718.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)

# %%
#!pip install twilio
# Out:
# Collecting twilio
#   Downloading twilio-9.5.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\lynix\anaconda3\lib\site-packages (from twilio) (2.32.3)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in c:\users\lynix\anaconda3\lib\site-packages (from twilio) (2.8.0)
# Requirement already satisfied: aiohttp>=3.8.4 in c:\users\lynix\anaconda3\lib\site-packages (from twilio) (3.10.5)
# Collecting aiohttp-retry>=2.8.3 (from twilio)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lynix\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lynix\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lynix\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lynix\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lynix\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2025.1.31)
# Downloading twilio-9.5.1-py2.py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.9 MB 762.0 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/1.9 MB 907.1 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.0/1.9 MB 986.7 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.9 MB 1.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.6/1.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 1.1 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Installing collected packages: aiohttp-retry, twilio
# Successfully installed aiohttp-retry-2.9.1 twilio-9.5.1
